# %% [markdown]
# ## Do these operation of data provided:
# * Read
# * Describe
# * Info

# %% [markdown]
# ## 1. XML data --> https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/student.xml

# %%
import pandas as pd

# %%
xml_data = pd.read_html("https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/student.xml")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-62daf951ea3f> in <module>
# ----> 1 xml_data = pd.read_html("https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/student.xml")
#
# c:\users\manishkc\appdata\local\programs\python\python37\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# c:\users\manishkc\appdata\local\programs\python\python37\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
# ...

# %% [markdown]
# ## 2. JSON datatype --> https://raw.githubusercontent.com/corysimmons/colors.json/master/colors.json

# %%
json_data = pd.read_json("https://raw.githubusercontent.com/corysimmons/colors.json/master/colors.json")

# %%
json_data.describe()
# Out:
#         aliceblue  antiquewhite        aqua  aquamarine       azure  \
# count    4.000000      4.000000    4.000000    4.000000    4.000000
# mean   186.000000    175.250000  127.750000  148.750000  187.750000
# std    123.485492    117.048067  146.936211  111.941577  124.700642
# min      1.000000      1.000000    0.000000    1.000000    1.000000
# 25%    180.250000    161.500000    0.750000   95.500000  180.250000
# 50%    244.000000    225.000000  128.000000  169.500000  247.500000
# 75%    249.750000    238.750000  255.000000  222.750000  255.000000
# max    255.000000    250.000000  255.000000  255.000000  255.000000
#
#             beige      bisque  black  blanchedalmond        blue  ...  \
# count    4.000000    4.000000   4.00        4.000000    4.000000  ...
# mean   177.750000  170.000000   0.25      174.000000   64.000000  ...
# std    118.421212  115.218633   0.50      117.149477  127.334206  ...
# min      1.000000    1.000000   0.00        1.000000    0.000000  ...
# ...

# %%
json_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Columns: 149 entries, aliceblue to rebeccapurple
# dtypes: int64(149)
# memory usage: 4.7 KB

# %% [markdown]
# ## 3. XLSX (Excel) --> https://github.com/edyoda/data-science-complete-tutorial/blob/master/Data/sales-funnel.xlsx

# %%
excel_data = pd.read_excel("sales-funnel.xlsx")

# %%
excel_data.describe()
# Out:
#              Account   Quantity          Price
# count      17.000000  17.000000      17.000000
# mean   462254.235294   1.764706   30705.882353
# std    259093.442862   1.032558   28444.605609
# min    141962.000000   1.000000    5000.000000
# 25%    218895.000000   1.000000    7000.000000
# 50%    412290.000000   2.000000   30000.000000
# 75%    714466.000000   2.000000   40000.000000
# max    740150.000000   5.000000  100000.000000

# %%
excel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
# Account     17 non-null int64
# Name        17 non-null object
# Rep         17 non-null object
# Manager     17 non-null object
# Product     17 non-null object
# Quantity    17 non-null int64
# Price       17 non-null int64
# Status      17 non-null object
# dtypes: int64(3), object(5)
# memory usage: 1.1+ KB

# %% [markdown]
# ## 4. Above data loaded from xlsx file create a pickle data from it and try to load that.

# %%
excel_data.to_pickle("sales.pkl")

# %%
pd.read_pickle("sales.pkl")
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %% [markdown]
# ## 5. Simple text data it can be read as csv . link--> https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/adult.data.txt

# %%
text_data = pd.read_csv("https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/adult.data.txt")

# %%
text_data.describe()
# Out:
#                  39         77516            13          2174             0  \
# count  32560.000000  3.256000e+04  32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05     10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05      2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  40
# count  32560.000000
# mean      40.437469
# std       12.347618
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
text_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
# 39                32560 non-null int64
#  State-gov        32560 non-null object
#  77516            32560 non-null int64
#  Bachelors        32560 non-null object
#  13               32560 non-null int64
#  Never-married    32560 non-null object
#  Adm-clerical     32560 non-null object
#  Not-in-family    32560 non-null object
#  White            32560 non-null object
#  Male             32560 non-null object
#  2174             32560 non-null int64
#  0                32560 non-null int64
#  40               32560 non-null int64
#  United-States    32560 non-null object
#  <=50K            32560 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
